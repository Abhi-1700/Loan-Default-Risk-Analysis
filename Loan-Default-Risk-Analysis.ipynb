# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
## 1. Import the dataset and understand it.

# %%
df_loan=pd.read_csv('loan.csv')
df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# ...

# %%
## information of the dataframe 
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  object
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %%
## data types of columns in the dataframe
df_loan.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate                object
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %%
##Shape of the dataframe 
df_loan.shape
# Out:
# (39717, 23)

# %%
##Question 2 :List down the number of rows and columns
num_rows, num_cols = df_loan.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 39717
# Number of columns: 24

# %%
##Question 3 :‘Int_rate’ column is character type. With the help of lambda function convert into float type
df_loan['int_rate'] = df_loan['int_rate'].apply(lambda x: float(x.strip('%')) if isinstance(x, str) else x)
df_loan
df_loan.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %%
##4. Check the datatype of each column ??
df_loan=pd.read_csv('loan.csv')
df_loan 
print(df_loan.dtypes)
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate                object
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %%
##5. Cleaning the dataset- Remove the columns having complete NaN value in the entire dataset ??

df_loan=pd.read_csv('loan.csv')
df_loan 
df_loan = df_loan.dropna(axis=1, how='all')
df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# ...

# %%
##6. Write the code to find the value counts of the ‘loan_status’ category column and filter only the ‘fully paid’ 
 ## and ‘charged off’ categories.
loan_status_counts = df_loan['loan_status'].value_counts()
print("Loan Status Value Counts:\n", loan_status_counts)
# Out:
# Loan Status Value Counts:
#  loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %%
## 7. Filter the ‘Emp_Len’ column to extract the numerical value from the string.
## Hint - Emp_len : < 1year, 2 years , 3 years as 1 , 2, 3 so on.
df_loan['emp_length_num']=df_loan.emp_length.str.extract('(\d+)')
df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#       int_rate  installment grade emp_length  ...   total_pymnt  \
# ...

# %%
# 8. Remove the month from the 'term' column----

df_loan['term'] = df_loan['term'].replace(' months', '', regex=True).astype(int)

# data['term'] = data['term'].apply(lambda x: int(x.strip(' months')))
df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#       int_rate  installment grade emp_length  ...             purpose    dti  \
# ...

# %%
# 9. Create a new column as risky_loan_applicant---
df_loan['risky_loan_applicant'] = np.where(df_loan['loan_amnt'] <= df_loan['funded_amnt'], '0', '1')

#  df_loan['risky_loan_applicant'] = '0'
#  df_loan.loc[data['loan_amnt'] > df_loan['funded_amnt'], 'risky_loan_applicant'] = '1'

df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#       int_rate  installment grade emp_length  ...    dti   total_pymnt  \
# ...

# %%
## 10. Using the bar plot visualize the loan_status column against categorical column grade, term, verification_status . 
## Write the observation from each graph.
categorical_cols = ['grade', 'term', 'verification_status']
for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    data.groupby([col, 'loan_status']).size().unstack().plot(kind='bar', stacked=True)
    plt.title(f'Loan Status vs {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.legend(title='Loan Status')
    plt.show()

# %%
## 11.Using a user defined function convert the ‘emp_len’ column into
##categorical column as follows -
## If emp_len is less than equals to 1 then recode as ‘fresher’.
##If emp_len is greater than 1 and less than 3 then recode as ‘junior’.
##If emp_len is greater than 3 and less than 7 then recode as ‘senior’
##If emp_len is greater than 7 then recode as ‘expert’.
# Convert emp_len to numeric
df_loan["emp_length"] = pd.to_numeric(df_loan["emp_length"], errors='coerce')
def categorize_emp_len(x):
    if x <= 1:
        return 'Fresher'
    elif 1 < x <= 3:
        return 'Junior'
    elif 3 < x <= 7:
        return 'Senior'
    else:
        return 'Expert'
df_loan["emp_length"] = df_loan["emp_length"].apply(categorize_emp_len)

df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#       int_rate  installment grade emp_length  ...   total_pymnt  \
# ...

# %%
## 12.Find the sum of ‘loan_amnt’ for each grade and display the distribution of ‘loan_amnt’ using a pie plot.
pie_data=df_loan.groupby('grade')['loan_amnt'].sum()
my_labels=['A','B','C','D','E','F','G']
pie_data
# Out:
# grade
# A     86982400
# B    133651350
# C     89115825
# D     65160400
# E     45037900
# F     19263100
# G      6391675
# Name: loan_amnt, dtype: int64

# %%
myexplode = [0,0.1, 0, 0, 0,0,0]
pie_data.plot.pie(labels=my_labels,explode=myexplode,shadow=True,title='Gross Loan Amount by Grade',autopct='%1.1f%%',
                  figsize=(6, 6))

# Here, we can understand that grade B has the highest loan amount
# Out:
# <Axes: title={'center': 'Gross Loan Amount by Grade'}, ylabel='loan_amnt'>
